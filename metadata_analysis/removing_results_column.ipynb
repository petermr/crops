# %%
import pandas as pd

# %%
df = pd.read_csv('liion_search_result.csv')

# %%
df_dropping_result = df.drop(['result', 'abstract', 'keywords'], axis = 1)

# %%
df_dropping_result.rename(columns = {'yake_keywords':'yake_keywords_from_results'}, inplace = True)

# %%
df_dropping_result
# Out:
#     Unnamed: 0                                      metadata_json      PMCIDS  \
# 0            0  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7040616
# 1            1  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7040742
# 2            2  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7048421
# 3            3  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7052225
# 4            4  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7052325
# 5            5  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7052380
# 6            6  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7055568
# 7            7  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7055569
# 8            8  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7057695
# 9            9  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7058583
# 10          10  C:\Users\shweata\openDiagram\physchem\liion\PM...  PMC7065120
# ...

# %%
df_dropping_result.to_csv('liion_key_phrases_from_results.csv')
